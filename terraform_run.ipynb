# %% [markdown]
# # 2. Terrafrom Run
#
# I commit the changes which triggers Terrafrom run.

# %% [markdown]
# ## 2.1. Terrafrom Plan indicates that it can successfully provision 6 resources on Amazon cloud.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It is ready to apply the plan:

# %% [markdown]
# ![image.png](attachment:image.png)
