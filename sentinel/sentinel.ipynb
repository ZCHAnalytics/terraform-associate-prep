# %% [markdown]
# # Enforce a policy
#
# Sentinel is an embedded policy-as-code framework integrated with various HashiCorp products.
#
# - sentinel.hcl
# - allowed-terraform-version.sentinel
#
# In Terraform Organisation > Settings > Policy Sets > Connect a policy set > GitHub

# %% [markdown]
# ![image.png](attachment:image.png)
