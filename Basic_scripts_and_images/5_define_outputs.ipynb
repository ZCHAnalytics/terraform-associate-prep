# %% [markdown]
# # 5. Query data with outputs
#
# I will use output values to present useful information to the Terraform user.
#
# # Create new file for outputs
#
# - Run `code outputs.tf`.
#
# # In the outputs file
# - Define outputs for the EC2 instance's ID and the public IP address

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, when I run `terraform apply`, I get outputs printed:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Release the resources
#
# In the end, I use `terraform destroy` to release the resources.
