# %% [markdown]
# # 6. Remote State
#
# ##  Add Terraform CLoud account
#
# Add terraform Cloud configuration settings inside the 'terraform'block in the main script.
#
# In the image below, see the code before and after the change:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 2. Login to Terraform Cloud
#
# Run `terraform login` in the terminal. Enter Terraform Token when generated. I can the following welcoming image:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For security, I store the token in
# the `.tfvars` file that can store sensitive data and is accessible only to authorized users. It will not be synched to the Terraform Cloud.
# For extra security I also added it to .gitignore in case I decide to use Github.

# %% [markdown]
# ## Initialise and migrate to the cloud
#
# Initialize Terraform

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Set Terraform Cloud environment variables - AWS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Run `terraform apply`

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Release the resources
#
# In the end, I use `terraform destroy` to release the resources.
