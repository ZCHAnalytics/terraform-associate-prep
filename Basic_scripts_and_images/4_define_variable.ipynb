# %% [markdown]
# # 4. Define variables
#
# I can use an input variable to parameterize the Terraform configuration.
#
# # Create new file to store variables
#
# - Run `code <filename>.tf`. I called mine `varibles.tf`
#
# # In the variables file
# - Add instance block
#
# # In the main file
# - In the `aws_instance` resource block update the tags to invlude a new variable . The Terraform CLI conviniently shows the variable for easy input.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Repeat this steps for the new configuration: 

- Write Configuration - `code main.tf`: Terraform Block {}, Providers, Resources
    Ubuntu 16.04 (arm64): https://cloud-images.ubuntu.com/locator/ec2
    instance type: "t4g.micro" to match ami
- Initialize the directory `terraform init`
- Format and validate the configuration `terraform fmt`, `terraform validate`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Test and Release the Resources
#
# After I apply this new plan, I release the resources.
