# %% [markdown]
# # 7. Destroy Infrastructure
#
# The `terraform destroy` command terminates resources managed by the Terraform project in the current working directory.

# %% [markdown]
# ![image.png](attachment:image.png)
