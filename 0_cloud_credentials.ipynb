# %% [markdown]
# # 0. Project credentials
#
# Currently the Terraform workspace does not have any credentials stored to allow the use of Amazon CLoud resources or my local IP range.  I don't have any resources created in my Amazon console. So I follow the following steps get relevant credentials that Terraform can use when planning and applying the code:
#
# ## 0.1. Create an IAM user in Amazon Web Service
# ## 0.2. Generate Access Keys
# ## 0.3. Add credentials to the Workspace in Terraform Cloud

# %% [markdown]
# My Amazon console in London is clean:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 0.1. Create a user called 'terraform'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 0.2. Generate Access Keys

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 0.3. Add environment variables to Terraform Workspace
#
# I added sensitive credentials to connect to AWS resources and also added IP address to use for inbound and outbound trafic:

# %% [markdown]
# ![image.png](attachment:image.png)
