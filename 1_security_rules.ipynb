# %% [markdown]
# # 1. Create Security Rules
#
# ## 1.1. Virtual Private Cloud
# Add resource block for a Virtual Private Cloud that will be referenced in the security group

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Create Security Group
#
# Add a new resource `aws_security_group` with an ID of VPC defined in Data source block:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 3. Add Security Rules to Security Group
#
# ### HTTP-inbound traffic rule
# resource "aws_security_group_rule" "web_inbound" {required parameters}
#
# ### HTTPS-inbound traffic rule
# resource "aws_security_group_rule" "web_secure_inbound" {required parameters}
#
# ### Outbound traffic rule
# resource "aws_security_group_rule" "web_outbound" {required parameters}

# %% [markdown]
# ## 3.1. Example of the inbound HTTP rule with all the parameters:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Add Security Group to EC3 instance definition block

# %% [markdown]
# ![image.png](attachment:image.png)
