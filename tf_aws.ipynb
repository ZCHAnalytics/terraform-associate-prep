# %% [markdown]
#  Create an AWS user and generate Access Key
#
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# Create a Version Control Workflow workspace:
#
# ![image.png](attachment:image.png)
#
# Add environment variables:
#
# ![ ](attachment:image-2.png)

# %% [markdown]
# Plan to deploy a TomCat server
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Apply
#
# ![image.png](attachment:image.png)

# %% [markdown]
# set VPC from Terraform Registry, select

# %% [markdown]
# load balancer and autoscaling group
#
# HTTP listener

# %% [markdown]
# Add variables/modules
