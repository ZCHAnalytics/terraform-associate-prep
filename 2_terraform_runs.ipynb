# %% [markdown]
# # 2 . Terraform Runs
#
# Pushing commits to GitHub automatically triggers a Terrafrom run which executes Terrafrom Plan and Apply.
#
# I check if the required AWS resources were deployed. The Web server is running as expected.

# %% [markdown]
# ![image.png](attachment:image.png)
